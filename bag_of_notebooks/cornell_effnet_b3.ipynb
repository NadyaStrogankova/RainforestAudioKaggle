# %%
# !sudo apt install -y libsndfile1
# !pip install numba==0.48
# !pip install git+https://github.com/fastaudio/fastaudio.git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-4ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.
# Collecting numba==0.48
#   Downloading https://files.pythonhosted.org/packages/23/7f/dbe85f5f419dca88509d829df90dfa5aefa39c39f6b7020dfc206a386279/numba-0.48.0-1-cp36-cp36m-manylinux2014_x86_64.whl (3.5MB)
#      |████████████████████████████████| 3.5MB 12.7MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba==0.48) (51.3.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from numba==0.48) (1.19.5)
# Collecting llvmlite<0.32.0,>=0.31.0dev0
#   Downloading https://files.pythonhosted.org/packages/ad/bb/60d4033d56c9da36490af19caa6c794b72b8aef6f792fdfa8cb95d11e419/llvmlite-0.31.0-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
#      |████████████████████████████████| 20.2MB 1.6MB/s
# ERROR: umap-learn 0.5.0 has requirement numba>=0.49, but you'll have numba 0.48.0 which is incompatible.
# ERROR: pynndescent 0.5.1 has requirement numba>=0.51.2, but you'll have numba 0.48.0 which is incompatible.
# Installing collected packages: llvmlite, numba
#   Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# Successfully installed llvmlite-0.31.0 numba-0.48.0
# Collecting git+https://github.com/fastaudio/fastaudio.git
#   Cloning https://github.com/fastaudio/fastaudio.git to /tmp/pip-req-build-ll1leepu
#   Running command git clone -q https://github.com/fastaudio/fastaudio.git /tmp/pip-req-build-ll1leepu
# Collecting fastai==2.1.9
#   Downloading https://files.pythonhosted.org/packages/0c/55/53a6e59561f97e6b2699e665d587aaf1502ea1efc428e17e17a1a7e23af1/fastai-2.1.9-py3-none-any.whl (190kB)
#      |████████████████████████████████| 194kB 13.8MB/s
# Collecting torchaudio>=0.6
#   Downloading https://files.pythonhosted.org/packages/2a/f9/618434cf4e46dc975871e1516f5499abef6564ab4366f9b2321ee536be14/torchaudio-0.7.2-cp36-cp36m-manylinux1_x86_64.whl (7.6MB)
#      |████████████████████████████████| 7.6MB 21.4MB/s
# Requirement already satisfied: librosa==0.8 in /usr/local/lib/python3.6/dist-packages (from fastaudio==0.1.4.post0.dev2+g8631a3f) (0.8.0)
# Collecting colorednoise>=1.1
#   Downloading https://files.pythonhosted.org/packages/a3/3e/85645bcaa5ba6003c6e3c650fe23c6352f7aa4a36eb1d700f3609e52963e/colorednoise-1.1.1.tar.gz
# Collecting IPython>=7.13
#   Downloading https://files.pythonhosted.org/packages/23/6a/210816c943c9aeeb29e4e18a298f14bf0e118fe222a23e13bfcc2d41b0a4/ipython-7.16.1-py3-none-any.whl (785kB)
#      |████████████████████████████████| 788kB 47.7MB/s
# Collecting fastcore==1.3.12
#   Downloading https://files.pythonhosted.org/packages/5c/ad/7c358331783cf8220e1bd0cca52df3e6092b3f6d4ce5b837fffbc9a64c53/fastcore-1.3.12-py3-none-any.whl (51kB)
#      |████████████████████████████████| 61kB 8.3MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (20.8)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.7.0+cu101)
# Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (7.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.1.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.22.2.post1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.2.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (3.13)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (3.2.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (19.3.1)
# Requirement already satisfied: torchvision>=0.8 in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.8.1+cu101)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.23.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.0.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (4.4.2)
# Requirement already satisfied: soundfile>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.10.3.post1)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.48.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.3.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.2.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.19.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (4.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (51.3.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.6/dist-packages (from IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.18.0)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/4e/f4/805f4596bf15ae8e576623f579b40c12b0780a7bdd9a437f205f136d9ece/prompt_toolkit-3.0.14-py3-none-any.whl (359kB)
#      |████████████████████████████████| 368kB 47.1MB/s
# Requirement already satisfied: backcall in /usr/local/lib/python3.6/dist-packages (from IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (4.8.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.4.7)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.7.0->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.16.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.7.0->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.7.0->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2018.9)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.8.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.1.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.10)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile>=0.9.0->librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.14.4)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.43.0->librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.31.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.6/dist-packages (from pooch>=1.0->librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.4.4)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.6/dist-packages (from resampy>=0.2.2->librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (1.15.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from jedi>=0.10->IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.8.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->IPython>=7.13->fastaudio==0.1.4.post0.dev2+g8631a3f) (0.7.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (3.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile>=0.9.0->librosa==0.8->fastaudio==0.1.4.post0.dev2+g8631a3f) (2.20)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy->fastai==2.1.9->fastaudio==0.1.4.post0.dev2+g8631a3f) (3.4.0)
# Building wheels for collected packages: fastaudio, colorednoise
#   Building wheel for fastaudio (setup.py) ... done
#   Created wheel for fastaudio: filename=fastaudio-0.1.4.post0.dev2+g8631a3f-py2.py3-none-any.whl size=18329 sha256=eadf002626f9eafe6452a038c23da3801756e43c43443606cefd5bd340aad104
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vjgj4_0n/wheels/20/af/b1/ea2a6d91971f5e3f435c6a0aa2ae8b7a010b644cc01e24b0ce
#   Building wheel for colorednoise (setup.py) ... done
#   Created wheel for colorednoise: filename=colorednoise-1.1.1-cp36-none-any.whl size=3958 sha256=09f2a7d43fef64bb90781b1ac801f69b900a21ab8922d7f3e873e4880b596d5d
#   Stored in directory: /root/.cache/pip/wheels/84/be/f3/3e7e1c80ebab3f6f0dbd3e34e787b902d2280d66706485fef4
# Successfully built fastaudio colorednoise
# ERROR: jupyter-console 5.2.0 has requirement prompt-toolkit<2.0.0,>=1.0.0, but you'll have prompt-toolkit 3.0.14 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement ipython~=5.5.0, but you'll have ipython 7.16.1 which is incompatible.
# ERROR: torchaudio 0.7.2 has requirement torch==1.7.1, but you'll have torch 1.7.0+cu101 which is incompatible.
# Installing collected packages: fastcore, fastai, torchaudio, colorednoise, prompt-toolkit, IPython, fastaudio
#   Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
#   Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
# Successfully installed IPython-7.16.1 colorednoise-1.1.1 fastai-2.1.9 fastaudio-0.1.4.post0.dev2+g8631a3f fastcore-1.3.12 prompt-toolkit-3.0.14 torchaudio-0.7.2

# %%
# !pip install timm
# !pip install efficientnet_pytorch
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.6/dist-packages (0.3.4)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.6/dist-packages (from timm) (1.7.0+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from timm) (0.8.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->timm) (3.7.4.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->timm) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->timm) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->timm) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision->timm) (7.0.0)
# Requirement already satisfied: efficientnet_pytorch in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from efficientnet_pytorch) (1.7.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (1.19.5)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (0.16.0)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torchaudio
torchaudio.set_audio_backend("sox_io")
# Out:
# /usr/local/lib/python3.6/dist-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '

# %%
import numpy as np
import pandas as pd
import os
import sys
sys.path.append("..")

import librosa as lr
import librosa.display

import soundfile as sf
import io

from pathlib import Path
from tqdm.notebook import tqdm

from fastaudio.core.all import *
from fastaudio.augment.all import *
from fastai.torch_basics import *
from fastai.basics import *
from fastai.data.all import *
from fastai.callback.all import *
from fastai.vision.all import *

import fastai
fastai.__version__
# Out:
# '2.1.8'

# %%
from google.colab import drive
drive.mount('/content/drive')# You must grant COLAB access to your Google Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/RainForestAudio/")
AUDIO_ROOT = Path(DATA_ROOT/"train/")
TRAIN_AUDIO_ROOT = Path(DATA_ROOT/"other_data")
#TRAIN_AUDIO_ROOT = Path("/content/samples_long")
#TRAIN_AUDIO_ROOT = Path("/content/samples_mixed")
TEST_AUDIO_ROOT = Path(DATA_ROOT/"test")
VAL_AUDIO_ROOT = Path(DATA_ROOT/"val")
df_train = pd.DataFrame([path.stem for path in Path(TRAIN_AUDIO_ROOT).glob("*.mp3")], columns=["recording_id"])
#train_folds = np.load(Path(DATA_ROOT/"folds.npy"), allow_pickle=True)
df_test = pd.DataFrame([path.stem for path in Path(TEST_AUDIO_ROOT).glob("*.flac")], columns=["recording_id"])
#df = pd.read_csv(Path(DATA_ROOT/"train.csv"))
df = pd.read_csv("/content/train_extended.csv")
print(df_train.shape, df_test.shape)
df
# Out:
# (0, 1) (0, 1)
#        rating  ...                                                    license
# 0         0.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 1         0.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 2         0.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 3         0.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 4         0.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# ...       ...  ...                                                        ...
# 23779     4.5  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 23780     4.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 23781     4.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 23782     3.5  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
# 23783     4.0  ...  Creative Commons Attribution-NonCommercial-ShareAlike 4.0
#
# [23784 rows x 29 columns]

# %%
import shutil
files = []
for row_1 in os.listdir(TRAIN_AUDIO_ROOT):
  #print(row_1)
  for row_2 in os.listdir(TRAIN_AUDIO_ROOT/row_1):
    #print(row_2)
    if len(os.listdir(TRAIN_AUDIO_ROOT/row_1/row_2)) < 100:
      print(row_1, row_2, "has not enough data")
      shutil.rmtree(TRAIN_AUDIO_ROOT/row_1/row_2)
    else:
      for fname in os.listdir(TRAIN_AUDIO_ROOT/row_1/row_2):
        if os.stat(TRAIN_AUDIO_ROOT/row_1/row_2/fname)[6] > 1e+6:
          print(row_1,row_2,fname, "to big", os.stat(TRAIN_AUDIO_ROOT/row_1/row_2/fname)[6], os.stat(TRAIN_AUDIO_ROOT/row_1/row_2/fname))
          os.remove(TRAIN_AUDIO_ROOT/row_1/row_2/fname)
        else: 
          files.append([fname.split(".")[0], row_2])

df_files = pd.DataFrame(files, columns=["fname", "species_id"])
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5)
train_index, val_index = list(skf.split(df_files['fname'], df_files["species_id"]))[0]
val_index
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# A-M easmea XC392958.mp3 to big 1652787 os.stat_result(st_mode=33152, st_ino=18365, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1652787, st_atime=1612184746, st_mtime=1600078860, st_ctime=1612184746)
# A-M easmea XC567185.mp3 to big 4524036 os.stat_result(st_mode=33152, st_ino=18353, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=4524036, st_atime=1612184749, st_mtime=1600078864, st_ctime=1612184749)
# A-M easmea XC563013.mp3 to big 4978467 os.stat_result(st_mode=33152, st_ino=18350, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=4978467, st_atime=1612184748, st_mtime=1600078864, st_ctime=1612184748)
# A-M easmea XC560755.mp3 to big 1396588 os.stat_result(st_mode=33152, st_ino=18349, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1396588, st_atime=1612184748, st_mtime=1600078864, st_ctime=1612184748)
# A-M easmea XC543306.mp3 to big 1421727 os.stat_result(st_mode=33152, st_ino=18338, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1421727, st_atime=1612184748, st_mtime=1600078864, st_ctime=1612184748)
# A-M easmea XC532986.mp3 to big 1748550 os.stat_result(st_mode=33152, st_ino=18332, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1748550, st_atime=1612184747, st_mtime=1600078862, st_ctime=1612184747)
# A-M easmea XC52429.mp3 to big 1205128 os.stat_result(st_mode=33152, st_ino=18330, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1205128, st_atime=1612184747, st_mtime=1600078862, st_ctime=1612184747)
# A-M easmea XC511402.mp3 to big 1631371 os.stat_result(st_mode=33152, st_ino=18328, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1631371, st_atime=1612184747, st_mtime=1600078862, st_ctime=1612184747)
# A-M easmea XC380928.mp3 to big 1763360 os.stat_result(st_mode=33152, st_ino=18319, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1763360, st_atime=1612184746, st_mtime=1600078860, st_ctime=1612184746)
# A-M easmea XC379528.mp3 to big 1604751 os.stat_result(st_mode=33152, st_ino=18318, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1604751, st_atime=1612184746, st_mtime=1600078860, st_ctime=1612184746)
# A-M easmea XC377106.mp3 to big 1907593 os.stat_result(st_mode=33152, st_ino=18315, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1907593, st_atime=1612184746, st_mtime=1600078858, st_ctime=1612184746)
# A-M easmea XC576834.mp3 to big 2265312 os.stat_result(st_mode=33152, st_ino=18310, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2265312, st_atime=1612184749, st_mtime=1600078866, st_ctime=1612184749)
# A-M easmea XC57307.mp3 to big 2727649 os.stat_result(st_mode=33152, st_ino=18307, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2727649, st_atime=1612184749, st_mtime=1600078866, st_ctime=1612184749)
# A-M easmea XC473682.mp3 to big 2169723 os.stat_result(st_mode=33152, st_ino=18303, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2169723, st_atime=1612184747, st_mtime=1600078862, st_ctime=1612184747)
# A-M easmea XC466337.mp3 to big 1070649 os.stat_result(st_mode=33152, st_ino=18302, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1070649, st_atime=1612184747, st_mtime=1600078862, st_ctime=1612184747)
# A-M easmea XC452612.mp3 to big 1286586 os.stat_result(st_mode=33152, st_ino=18298, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1286586, st_atime=1612184747, st_mtime=1600078862, st_ctime=1612184747)
# A-M easmea XC327565.mp3 to big 1642955 os.stat_result(st_mode=33152, st_ino=18271, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1642955, st_atime=1612184745, st_mtime=1600078858, st_ctime=1612184745)
# A-M easmea XC322685.mp3 to big 1308933 os.stat_result(st_mode=33152, st_ino=18270, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1308933, st_atime=1612184745, st_mtime=1600078858, st_ctime=1612184745)
# A-M easmea XC317562.mp3 to big 1014972 os.stat_result(st_mode=33152, st_ino=18264, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1014972, st_atime=1612184745, st_mtime=1600078858, st_ctime=1612184745)
# A-M easmea XC316510.mp3 to big 2333799 os.stat_result(st_mode=33152, st_ino=18263, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2333799, st_atime=1612184745, st_mtime=1600078858, st_ctime=1612184745)
# A-M easmea XC313358.mp3 to big 1232722 os.stat_result(st_mode=33152, st_ino=18260, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1232722, st_atime=1612184745, st_mtime=1600078858, st_ctime=1612184745)
# A-M easmea XC306357.mp3 to big 1177220 os.stat_result(st_mode=33152, st_ino=18255, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1177220, st_atime=1612184745, st_mtime=1600078856, st_ctime=1612184745)
# A-M easmea XC293619.mp3 to big 1149135 os.stat_result(st_mode=33152, st_ino=18252, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1149135, st_atime=1612184745, st_mtime=1600078856, st_ctime=1612184745)
# A-M easmea XC268264.mp3 to big 1085578 os.stat_result(st_mode=33152, st_ino=18249, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1085578, st_atime=1612184744, st_mtime=1600078856, st_ctime=1612184744)
# A-M easmea XC173555.mp3 to big 2832057 os.stat_result(st_mode=33152, st_ino=18243, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2832057, st_atime=1612184743, st_mtime=1600078856, st_ctime=1612184743)
# A-M easmea XC173554.mp3 to big 1847962 os.stat_result(st_mode=33152, st_ino=18242, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1847962, st_atime=1612184743, st_mtime=1600078854, st_ctime=1612184743)
# A-M easmea XC172950.mp3 to big 1295602 os.stat_result(st_mode=33152, st_ino=18241, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1295602, st_atime=1612184743, st_mtime=1600078854, st_ctime=1612184743)
# A-M easmea XC357865.mp3 to big 1749119 os.stat_result(st_mode=33152, st_ino=18239, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1749119, st_atime=1612184746, st_mtime=1600078858, st_ctime=1612184746)
# A-M easmea XC429254.mp3 to big 1090591 os.stat_result(st_mode=33152, st_ino=18227, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1090591, st_atime=1612184747, st_mtime=1600078860, st_ctime=1612184747)
# A-M easmea XC244901.mp3 to big 2227362 os.stat_result(st_mode=33152, st_ino=18224, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2227362, st_atime=1612184744, st_mtime=1600078856, st_ctime=1612184744)
# A-M easmea XC391916.mp3 to big 1461044 os.stat_result(st_mode=33152, st_ino=18216, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1461044, st_atime=1612184746, st_mtime=1600078860, st_ctime=1612184746)
# A-M easmea XC391587.mp3 to big 3082086 os.stat_result(st_mode=33152, st_ino=18215, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=3082086, st_atime=1612184746, st_mtime=1600078860, st_ctime=1612184746)
# A-M easmea XC560752.mp3 to big 2998463 os.stat_result(st_mode=33152, st_ino=18206, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2998463, st_atime=1612184748, st_mtime=1600078864, st_ctime=1612184748)
# A-M easmea XC549414.mp3 to big 1108033 os.stat_result(st_mode=33152, st_ino=18204, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1108033, st_atime=1612184748, st_mtime=1600078864, st_ctime=1612184748)
# A-M easmea XC490451.mp3 to big 2201341 os.stat_result(st_mode=33152, st_ino=18202, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2201341, st_atime=1612184747, st_mtime=1600078862, st_ctime=1612184747)
# A-M easmea XC336696.mp3 to big 2789697 os.stat_result(st_mode=33152, st_ino=18189, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2789697, st_atime=1612184746, st_mtime=1600078858, st_ctime=1612184746)
# A-M easmea XC420917.mp3 to big 1073163 os.stat_result(st_mode=33152, st_ino=18178, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1073163, st_atime=1612184747, st_mtime=1600078860, st_ctime=1612184747)
# A-M easmea XC172948.mp3 to big 1239445 os.stat_result(st_mode=33152, st_ino=18168, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1239445, st_atime=1612184743, st_mtime=1600078854, st_ctime=1612184743)
# A-M easmea XC132662.mp3 to big 2130798 os.stat_result(st_mode=33152, st_ino=18162, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2130798, st_atime=1612184743, st_mtime=1600078854, st_ctime=1612184743)
# A-M easmea XC216427.mp3 to big 1697591 os.stat_result(st_mode=33152, st_ino=18126, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1697591, st_atime=1612184744, st_mtime=1600078856, st_ctime=1612184744)
# A-M easmea XC193962.mp3 to big 1335908 os.stat_result(st_mode=33152, st_ino=18124, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1335908, st_atime=1612184744, st_mtime=1600078856, st_ctime=1612184744)
# A-M daejun XC97210.mp3 to big 1260358 os.stat_result(st_mode=33152, st_ino=18119, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1260358, st_atime=1612184736, st_mtime=1600078840, st_ctime=1612184736)
# A-M daejun XC96803.mp3 to big 1070633 os.stat_result(st_mode=33152, st_ino=18116, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1070633, st_atime=1612184736, st_mtime=1600078840, st_ctime=1612184736)
# A-M daejun XC67153.mp3 to big 2416520 os.stat_result(st_mode=33152, st_ino=18114, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2416520, st_atime=1612184736, st_mtime=1600078840, st_ctime=1612184736)
# A-M daejun XC571059.mp3 to big 1619635 os.stat_result(st_mode=33152, st_ino=18072, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1619635, st_atime=1612184736, st_mtime=1600078838, st_ctime=1612184736)
# A-M daejun XC571058.mp3 to big 2097691 os.stat_result(st_mode=33152, st_ino=18071, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2097691, st_atime=1612184736, st_mtime=1600078838, st_ctime=1612184736)
# A-M daejun XC571057.mp3 to big 2086037 os.stat_result(st_mode=33152, st_ino=18070, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2086037, st_atime=1612184736, st_mtime=1600078838, st_ctime=1612184736)
# A-M daejun XC571054.mp3 to big 1313556 os.stat_result(st_mode=33152, st_ino=18068, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1313556, st_atime=1612184736, st_mtime=1600078838, st_ctime=1612184736)
# A-M daejun XC571053.mp3 to big 2392928 os.stat_result(st_mode=33152, st_ino=18066, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=
st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=15258920, st_atime=1612184723, st_mtime=1600078810, st_ctime=1612184723)
# A-M daejun XC213749.mp3 to big 1389448 os.stat_result(st_mode=33152, st_ino=17908, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1389448, st_atime=1612184723, st_mtime=1600078808, st_ctime=1612184723)
# A-M daejun XC206100.mp3 to big 1660697 os.stat_result(st_mode=33152, st_ino=17906, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1660697, st_atime=1612184723, st_mtime=1600078808, st_ctime=1612184723)
# A-M daejun XC205538.mp3 to big 2096658 os.stat_result(st_mode=33152, st_ino=17905, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2096658, st_atime=1612184723, st_mtime=1600078808, st_ctime=1612184723)
# A-M daejun XC368608.mp3 to big 1853735 os.stat_result(st_mode=33152, st_ino=17899, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1853735, st_atime=1612184728, st_mtime=1600078820, st_ctime=1612184728)
# A-M daejun XC368605.mp3 to big 1105895 os.stat_result(st_mode=33152, st_ino=17896, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1105895, st_atime=1612184728, st_mtime=1600078820, st_ctime=1612184728)
# A-M daejun XC269462.mp3 to big 2810842 os.stat_result(st_mode=33152, st_ino=17886, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2810842, st_atime=1612184726, st_mtime=1600078814, st_ctime=1612184726)
# A-M daejun XC269461.mp3 to big 1004686 os.stat_result(st_mode=33152, st_ino=17885, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1004686, st_atime=1612184726, st_mtime=1600078814, st_ctime=1612184726)
# A-M daejun XC269460.mp3 to big 2839125 os.stat_result(st_mode=33152, st_ino=17884, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2839125, st_atime=1612184725, st_mtime=1600078814, st_ctime=1612184725)
# A-M daejun XC362106.mp3 to big 1352575 os.stat_result(st_mode=33152, st_ino=17883, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1352575, st_atime=1612184728, st_mtime=1600078818, st_ctime=1612184728)
# A-M daejun XC362102.mp3 to big 1185535 os.stat_result(st_mode=33152, st_ino=17879, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1185535, st_atime=1612184728, st_mtime=1600078818, st_ctime=1612184728)
# A-M daejun XC358193.mp3 to big 1213404 os.stat_result(st_mode=33152, st_ino=17878, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1213404, st_atime=1612184727, st_mtime=1600078818, st_ctime=1612184727)
# A-M daejun XC358194.mp3 to big 1355503 os.stat_result(st_mode=33152, st_ino=17877, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1355503, st_atime=1612184727, st_mtime=1600078818, st_ctime=1612184727)
# A-M daejun XC349618.mp3 to big 2272158 os.stat_result(st_mode=33152, st_ino=17876, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2272158, st_atime=1612184727, st_mtime=1600078818, st_ctime=1612184727)
# A-M daejun XC323125.mp3 to big 1397775 os.stat_result(st_mode=33152, st_ino=17871, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1397775, st_atime=1612184727, st_mtime=1600078816, st_ctime=1612184727)
# A-M daejun XC314957.mp3 to big 1166474 os.stat_result(st_mode=33152, st_ino=17869, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1166474, st_atime=1612184727, st_mtime=1600078816, st_ctime=1612184727)
# A-M daejun XC269060.mp3 to big 1175254 os.stat_result(st_mode=33152, st_ino=17867, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1175254, st_atime=1612184725, st_mtime=1600078814, st_ctime=1612184725)
# A-M daejun XC269055.mp3 to big 1000881 os.stat_result(st_mode=33152, st_ino=17866, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1000881, st_atime=1612184725, st_mtime=1600078814, st_ctime=1612184725)
# A-M daejun XC267990.mp3 to big 3661307 os.stat_result(st_mode=33152, st_ino=17864, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=3661307, st_atime=1612184725, st_mtime=1600078812, st_ctime=1612184725)
# A-M daejun XC247781.mp3 to big 1962161 os.stat_result(st_mode=33152, st_ino=17852, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1962161, st_atime=1612184725, st_mtime=1600078812, st_ctime=1612184725)
# A-M daejun XC234176.mp3 to big 1376853 os.stat_result(st_mode=33152, st_ino=17847, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1376853, st_atime=1612184725, st_mtime=1600078812, st_ctime=1612184725)
# A-M daejun XC218796.mp3 to big 2862329 os.stat_result(st_mode=33152, st_ino=17841, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2862329, st_atime=1612184724, st_mtime=1600078810, st_ctime=1612184724)
# A-M daejun XC218793.mp3 to big 1805068 os.stat_result(st_mode=33152, st_ino=17840, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1805068, st_atime=1612184724, st_mtime=1600078810, st_ctime=1612184724)
# A-M daejun XC163625.mp3 to big 1024243 os.stat_result(st_mode=33152, st_ino=17835, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1024243, st_atime=1612184722, st_mtime=1600078806, st_ctime=1612184722)
# A-M daejun XC161150.mp3 to big 2384818 os.stat_result(st_mode=33152, st_ino=17834, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2384818, st_atime=1612184722, st_mtime=1600078806, st_ctime=1612184722)
# A-M daejun XC153395.mp3 to big 1125305 os.stat_result(st_mode=33152, st_ino=17831, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1125305, st_atime=1612184722, st_mtime=1600078806, st_ctime=1612184722)
# A-M daejun XC149907.mp3 to big 1394784 os.stat_result(st_mode=33152, st_ino=17828, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1394784, st_atime=1612184721, st_mtime=1600078806, st_ctime=1612184721)
# A-M daejun XC149906.mp3 to big 1126030 os.stat_result(st_mode=33152, st_ino=17827, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1126030, st_atime=1612184721, st_mtime=1600078806, st_ctime=1612184721)
# A-M daejun XC313672.mp3 to big 1048163 os.stat_result(st_mode=33152, st_ino=17824, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1048163, st_atime=1612184727, st_mtime=1600078816, st_ctime=1612184727)
# A-M daejun XC306660.mp3 to big 1972191 os.stat_result(st_mode=33152, st_ino=17823, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1972191, st_atime=1612184726, st_mtime=1600078816, st_ctime=1612184726)
# A-M daejun XC293801.mp3 to big 1541757 os.stat_result(st_mode=33152, st_ino=17820, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1541757, st_atime=1612184726, st_mtime=1600078816, st_ctime=1612184726)
# A-M daejun XC146597.mp3 to big 1221658 os.stat_result(st_mode=33152, st_ino=17816, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1221658, st_atime=1612184721, st_mtime=1600078806, st_ctime=1612184721)
# A-M daejun XC146596.mp3 to big 1110922 os.stat_result(st_mode=33152, st_ino=17815, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1110922, st_atime=1612184721, st_mtime=1600078806, st_ctime=1612184721)
# A-M daejun XC142589.mp3 to big 1222677 os.stat_result(st_mode=33152, st_ino=17813, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1222677, st_atime=1612184721, st_mtime=1600078804, st_ctime=1612184721)
# A-M daejun XC192493.mp3 to big 1426427 os.stat_result(st_mode=33152, st_ino=17808, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1426427, st_atime=1612184722, st_mtime=1600078808, st_ctime=1612184722)
# A-M daejun XC188356.mp3 to big 2047095 os.stat_result(st_mode=33152, st_ino=17807, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2047095, st_atime=1612184722, st_mtime=1600078808, st_ctime=1612184722)
# A-M daejun XC187271.mp3 to big 1997535 os.stat_result(st_mode=33152, st_ino=17804, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1997535, st_atime=1612184722, st_mtime=1600078808, st_ctime=1612184722)
# A-M daejun XC174554.mp3 to big 1702958 os.stat_result(st_mode=33152, st_ino=17801, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1702958, st_atime=1612184722, st_mtime=1600078808, st_ctime=1612184722)
# A-M daejun XC172444.mp3 to big 1364660 os.stat_result(st_mode=33152, st_ino=17799, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1364660, st_atime=1612184722, st_mtime=1600078806, st_ctime=1612184722)
# A-M daejun XC125071.mp3 to big 1169429 os.stat_result(st_mode=33152, st_ino=17794, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1169429, st_atime=1612184721, st_mtime=1600078804, st_ctime=1612184721)
# A-M daejun XC169519.mp3 to big 1376010 os.stat_result(st_mode=33152, st_ino=17780, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1376010, st_atime=1612184722, st_mtime=1600078806, st_ctime=1612184722)
# A-M daejun XC129077.mp3 to big 5095634 os.stat_result(st_mode=33152, st_ino=17777, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=5095634, st_atime=1612184721, st_mtime=1600078804, st_ctime=1612184721)
# A-M daejun XC218787.mp3 to big 1029410 os.stat_result(st_mode=33152, st_ino=17772, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1029410, st_atime=1612184724, st_mtime=1600078810, st_ctime=1612184724)
# A-M daejun XC253373.mp3 to big 1081799 os.stat_result(st_mode=33152, st_ino=17771, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1081799, st_atime=1612184725, st_mtime=1600078812, st_ctime=1612184725)
# A-M daejun XC253841.mp3 to big 2809842 os.stat_result(st_mode=33152, st_ino=17741, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2809842, st_atime=1612184725, st_mtime=1600078812, st_ctime=1612184725)
# A-M daejun XC253586.mp3 to big 4224781 os.stat_result(st_mode=33152, st_ino=17740, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=4224781, st_atime=1612184725, st_mtime=1600078812, st_ctime=1612184725)
# A-M gnwtea XC546743.mp3 to big 1718353 os.stat_result(st_mode=33152, st_ino=19961, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1718353, st_atime=1612184886, st_mtime=1600079180, st_ctime=1612184886)
# A-M gnwtea XC546087.mp3 to big 1429960 os.stat_result(st_mode=33152, st_ino=19960, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1429960, st_atime=1612184886, st_mtime=1600079180, st_ctime=1612184886)
# A-M gnwtea XC554855.mp3 to big 5034563 os.stat_result(st_mode=33152, st_ino=19948, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=5034563, st_atime=1612184886, st_mtime=1600079180, st_ctime=1612184886)
# A-M gnwtea XC542098.mp3 to big 1295886 os.stat_result(st_mode=33152, st_ino=19900, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1295886, st_atime=1612184885, st_mtime=1600079180, st_ctime=1612184885)
# A-M gnwtea XC537666.mp3 to big 3906408 os.stat_result(st_mode=33152, st_ino=19894, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=3906408, st_atime=1612184885, st_mtime=1600079178, st_ctime=1612184885)
# A-M gnwtea XC533241.mp3 to big 2181228 os.stat_result(st_mode=33152, st_ino=19891, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2181228, st_atime=1612184885, st_mtime=1600079178, st_ctime=1612184885)
# A-M gnwtea XC520657.mp3 to big 1890800 os.stat_result(st_mode=33152, st_ino=19876, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1890800, st_atime=1612184884, st_mtime=1600079176, st_ctime=1612184884)
# A-M gnwtea XC533237.mp3 to big 2563661 os.stat_result(st_mode=33152, st_ino=19875, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2563661, st_atime=1612184885, st_mtime=1600079178, st_ctime=1612184885)
# A-M gnwtea XC533235.mp3 to big 3021326 os.stat_result(st_mode=33152, st_ino=19873, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=3021326, st_atime=1612184885, st_mtime=1600079178, st_ctime=1612184885)
# A-M gnwtea XC533234.mp3 to big 2498877 os.stat_result(st_mode=33152, st_ino=19872, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2498877, st_atime=1612184884, st_mtime=1600079178, st_ctime=1612184884)
# A-M gnwtea XC528093.mp3 to big 1056955 os.stat_result(st_mode=33152, st_ino=19866, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1056955, st_atime=1612184884, st_mtime=1600079178, st_ctime=1612184884)
# A-M gnwtea XC522916.mp3 to big 1983785 os.stat_result(st_mode=33152, st_ino=19822, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1983785, st_atime=1612184884, st_mtime=1600079176, st_ctime=1612184884)
# A-M gnwtea XC304197.mp3 to big 1124675 os.stat_result(st_mode=33152, st_ino=19814, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1124675, st_atime=1612184881, st_mtime=1600079172, st_ctime=1612184881)
# A-M gnwtea XC522917.mp3 to big 1052778 os.stat_result(st_mode=33152, st_ino=19804, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1052778, st_atime=1612184884, st_mtime=1600079176, st_ctime=1612184884)
# A-M gnwtea XC520583.mp3 to big 1103839 os.stat_result(st_mode=33152, st_ino=19803, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1103839, st_atime=1612184884, st_mtime=1600079176, st_ctime=1612184884)
# A-M gnwtea XC516301.mp3 to big 1194417 os.stat_result(st_mode=33152, st_ino=19802, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1194417, st_atime=1612184884, st_mtime=1600079176, st_ctime=1612184884)
# A-M gnwtea XC533239.mp3 to big 1706844 os.stat_result(st_mode=33152, st_ino=19798, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1706844, st_atime=1612184885, st_mtime=1600079178, st_ctime=1612184885)
# A-M gnwtea XC447824.mp3 to big 2393727 os.stat_result(st_mode=33152, st_ino=19797, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2393727, st_atime=1612184882, st_mtime=1600079174, st_ctime=1612184882)
# A-M gnwtea XC432030.mp3 to big 2247252 os.stat_result(st_mode=33152, st_ino=19790, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2247252, st_atime=1612184881, st_mtime=1600079174, st_ctime=1612184881)
# A-M gnwtea XC461203.mp3 to big 2136807 os.stat_result(st_mode=33152, st_ino=19782, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2136807, st_atime=1612184882, st_mtime=1600079174, st_ctime=1612184882)
# A-M gnwtea XC458098.mp3 to big 2722493 os.stat_result(st_mode=33152, st_ino=19780, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2722493, st_atime=1612184882, st_mtime=1600079174, st_ctime=1612184882)
# A-M gnwtea XC169591.mp3 to big 1126002 os.stat_result(st_mode=33152, st_ino=19756, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1126002, st_atime=1612184880, st_mtime=1600079172, st_ctime=1612184880)
# A-M gnwtea XC182409.mp3 to big 1246533 os.stat_result(st_mode=33152, st_ino=19755, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1246533, st_atime=1612184880, st_mtime=1600079172, st_ctime=1612184880)
# A-M gnwtea XC131653.mp3 to big 1102440 os.stat_result(st_mode=33152, st_ino=19724, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1102440, st_atime=1612184880, st_mtime=1600079170, st_ctime=1612184880)
# A-M gnwtea XC266794.mp3 to big 1066795 os.stat_result(st_mode=33152, st_ino=19701, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1066795, st_atime=1612184881, st_mtime=1600079172, st_ctime=1612184881)
# A-M gnwtea XC412525.mp3 to big 1184506 os.stat_result(st_mode=33152, st_ino=19696, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1184506, st_atime=1612184881, st_mtime=1600079172, st_ctime=1612184881)
# A-M gnwtea XC396539.mp3 to big 4801588 os.stat_result(st_mode=33152, st_ino=19695, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=4801588, st_atime=1612184881, st_mtime=1600079172, st_ctime=1612184881)
# A-M comyel XC86758.mp3 to big 1125747 os.stat_result(st_mode=33152, st_ino=17750, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1125747, st_atime=1612184718, st_mtime=1600078798, st_ctime=1612184718)
# A-M comyel XC80734.mp3 to big 1298372 os.stat_result(st_mode=33152, st_ino=17749, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1298372, st_atime=1612184718, st_mtime=1600078798, st_ctime=1612184718)
# A-M comyel XC576171.mp3 to big 1684784 os.stat_result(st_mode=33152, st_ino=17736, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1684784, st_atime=1612184717, st_mtime=1600078794, st_ctime=1612184717)
# A-M comyel XC576233.mp3 to big 2296329 os.stat_result(st_mode=33152, st_ino=17735, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2296329, st_atime=1612184717, st_mtime=1600078794, st_ctime=1612184717)
# A-M comyel XC575678.mp3 to big 2317142 os.stat_result(st_mode=33152, st_ino=17734, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2317142, st_atime=1612184717, st_mtime=1600078794, st_ctime=1612184717)
# A-M comyel XC575679.mp3 to big 1090389 os.stat_result(st_mode=33152, st_ino=17733, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1090389, st_atime=1612184717, st_mtime=1600078794, st_ctime=1612184717)
# A-M comyel XC573424.mp3 to big 1131572 os.stat_result(st_mode=33152, st_ino=17730, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1131572, st_atime=1612184716, st_mtime=1600078794, st_ctime=1612184716)
# A-M comyel XC574257.mp3 to big 2574493 os.stat_result(st_mode=33152, st_ino=17729, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2574493, st_atime=1612184716, st_mtime=1600078794, st_ctime=1612184716)
# A-M comyel XC573143.mp3 to big 4033889 os.stat_result(st_mode=33152, st_ino=17728, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=4033889, st_atime=1612184716, st_mtime=1600078794, st_ctime=1612184716)
# A-M comyel XC573142.mp3 to big 2063002 os.stat_result(st_mode=33152, st_ino=17727, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2063002, st_atime=1612184716, st_mtime=1600078794, st_ctime=1612184716)
# A-M comyel XC573141.mp3 to big 1601249 os.stat_result(st_mode=33152, st_ino=17726, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1601249, st_atime=1612184716, st_mtime=1600078794, st_ctime=1612184716)
# A-M comyel XC580992.mp3 to big 1938345 os.stat_result(st_mode=33152, st_ino=17721, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1938345, st_atime=1612184718, st_mtime=1600078796, st_ctime=1612184718)
# A-M comyel XC579149.mp3 to big 1784262 os.stat_result(st_mode=33152, st_ino=17720, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1784262, st_atime=1612184717, st_mtime=1600078796, st_ctime=1612184717)
# A-M comyel XC579148.mp3 to big 2446773 os.stat_result(st_mode=33152, st_ino=17719, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2446773, st_atime=1612184717, st_mtime=1600078796, st_ctime=1612184717)
# A-M comyel XC578117.mp3 to big 3744999 os.stat_result(st_mode=33152, st_ino=17717, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=3744999, st_atime=1612184717, st_mtime=1600078796, st_ctime=1612184717)
# A-M comyel XC578116.mp3 to big 2772515 os.stat_result(st_mode=33152, st_ino=17716, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2772515, st_atime=1612184717, st_mtime=1600078796, st_ctime=1612184717)
# A-M comyel XC577543.mp3 to big 2102375 os.stat_result(st_mode=33152, st_ino=17714, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2102375, st_atime=1612184717, st_mtime=1600078796, st_ctime=1612184717)
# A-M comyel XC551090.mp3 to big 1355478 os.stat_result(st_mode=33152, st_ino=17708, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1355478, st_atime=1612184714, st_mtime=1600078788, st_ctime=1612184714)
# A-M comyel XC551062.mp3 to big 1944962 os.stat_result(st_mode=33152, st_ino=17707, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1944962, st_atime=1612184714, st_mtime=1600078788, st_ctime=1612184714)
# A-M comyel XC538364.mp3 to big 3688287 os.stat_result(st_mode=33152, st_ino=17702, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size
st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1080113, st_atime=1612193928, st_mtime=1600082638, st_ctime=1612193928)
# N-Z woothr XC316022.mp3 to big 1287372 os.stat_result(st_mode=33152, st_ino=59684, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1287372, st_atime=1612193928, st_mtime=1600082638, st_ctime=1612193928)
# N-Z woothr XC317731.mp3 to big 2106455 os.stat_result(st_mode=33152, st_ino=59686, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2106455, st_atime=1612193928, st_mtime=1600082638, st_ctime=1612193928)
# N-Z woothr XC317956.mp3 to big 1561108 os.stat_result(st_mode=33152, st_ino=59688, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1561108, st_atime=1612193928, st_mtime=1600082638, st_ctime=1612193928)
# N-Z woothr XC317957.mp3 to big 1435728 os.stat_result(st_mode=33152, st_ino=59690, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1435728, st_atime=1612193929, st_mtime=1600082638, st_ctime=1612193929)
# N-Z woothr XC320095.mp3 to big 1168024 os.stat_result(st_mode=33152, st_ino=59696, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1168024, st_atime=1612193929, st_mtime=1600082638, st_ctime=1612193929)
# N-Z woothr XC321167.mp3 to big 1798586 os.stat_result(st_mode=33152, st_ino=59702, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1798586, st_atime=1612193929, st_mtime=1600082640, st_ctime=1612193929)
# N-Z woothr XC321880.mp3 to big 1011226 os.stat_result(st_mode=33152, st_ino=59705, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1011226, st_atime=1612193929, st_mtime=1600082640, st_ctime=1612193929)
# N-Z woothr XC323213.mp3 to big 1048641 os.stat_result(st_mode=33152, st_ino=59707, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1048641, st_atime=1612193929, st_mtime=1600082640, st_ctime=1612193929)
# N-Z woothr XC323219.mp3 to big 1681896 os.stat_result(st_mode=33152, st_ino=59710, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1681896, st_atime=1612193929, st_mtime=1600082640, st_ctime=1612193929)
# N-Z woothr XC323226.mp3 to big 1225888 os.stat_result(st_mode=33152, st_ino=59712, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1225888, st_atime=1612193930, st_mtime=1600082640, st_ctime=1612193930)
# N-Z woothr XC323991.mp3 to big 1630859 os.stat_result(st_mode=33152, st_ino=59714, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1630859, st_atime=1612193930, st_mtime=1600082640, st_ctime=1612193930)
# N-Z woothr XC335344.mp3 to big 1457273 os.stat_result(st_mode=33152, st_ino=59720, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1457273, st_atime=1612193930, st_mtime=1600082640, st_ctime=1612193930)
# N-Z woothr XC354659.mp3 to big 1014076 os.stat_result(st_mode=33152, st_ino=59722, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1014076, st_atime=1612193930, st_mtime=1600082640, st_ctime=1612193930)
# N-Z woothr XC375498.mp3 to big 12121303 os.stat_result(st_mode=33152, st_ino=59724, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=12121303, st_atime=1612193930, st_mtime=1600082640, st_ctime=1612193930)
# N-Z woothr XC381082.mp3 to big 2017971 os.stat_result(st_mode=33152, st_ino=59727, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2017971, st_atime=1612193930, st_mtime=1600082642, st_ctime=1612193930)
# N-Z woothr XC421293.mp3 to big 1635918 os.stat_result(st_mode=33152, st_ino=59741, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1635918, st_atime=1612193931, st_mtime=1600082644, st_ctime=1612193931)
# N-Z woothr XC426231.mp3 to big 1894118 os.stat_result(st_mode=33152, st_ino=59743, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1894118, st_atime=1612193931, st_mtime=1600082644, st_ctime=1612193931)
# N-Z woothr XC444970.mp3 to big 1998315 os.stat_result(st_mode=33152, st_ino=59746, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1998315, st_atime=1612193931, st_mtime=1600082644, st_ctime=1612193931)
# N-Z woothr XC460084.mp3 to big 3347142 os.stat_result(st_mode=33152, st_ino=59748, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=3347142, st_atime=1612193931, st_mtime=1600082644, st_ctime=1612193931)
# N-Z woothr XC469606.mp3 to big 2628813 os.stat_result(st_mode=33152, st_ino=59754, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2628813, st_atime=1612193931, st_mtime=1600082644, st_ctime=1612193931)
# N-Z woothr XC471021.mp3 to big 4681058 os.stat_result(st_mode=33152, st_ino=59756, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=4681058, st_atime=1612193931, st_mtime=1600082644, st_ctime=1612193931)
# N-Z woothr XC478581.mp3 to big 2544683 os.stat_result(st_mode=33152, st_ino=59760, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2544683, st_atime=1612193931, st_mtime=1600082646, st_ctime=1612193931)
# N-Z woothr XC483768.mp3 to big 1283646 os.stat_result(st_mode=33152, st_ino=59764, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1283646, st_atime=1612193931, st_mtime=1600082646, st_ctime=1612193931)
# N-Z woothr XC497716.mp3 to big 1187573 os.stat_result(st_mode=33152, st_ino=59768, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1187573, st_atime=1612193932, st_mtime=1600082646, st_ctime=1612193932)
# N-Z woothr XC499567.mp3 to big 2496909 os.stat_result(st_mode=33152, st_ino=59770, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2496909, st_atime=1612193932, st_mtime=1600082646, st_ctime=1612193932)
# N-Z woothr XC543749.mp3 to big 1990048 os.stat_result(st_mode=33152, st_ino=59772, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1990048, st_atime=1612193932, st_mtime=1600082646, st_ctime=1612193932)
# N-Z woothr XC552876.mp3 to big 2383947 os.stat_result(st_mode=33152, st_ino=59776, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2383947, st_atime=1612193932, st_mtime=1600082646, st_ctime=1612193932)
# N-Z woothr XC554196.mp3 to big 1585265 os.stat_result(st_mode=33152, st_ino=59778, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1585265, st_atime=1612193932, st_mtime=1600082648, st_ctime=1612193932)
# N-Z woothr XC555446.mp3 to big 1362619 os.stat_result(st_mode=33152, st_ino=59782, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1362619, st_atime=1612193932, st_mtime=1600082648, st_ctime=1612193932)
# N-Z woothr XC556729.mp3 to big 1242437 os.stat_result(st_mode=33152, st_ino=59784, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1242437, st_atime=1612193932, st_mtime=1600082648, st_ctime=1612193932)
# N-Z woothr XC561864.mp3 to big 7011536 os.stat_result(st_mode=33152, st_ino=59786, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=7011536, st_atime=1612193932, st_mtime=1600082648, st_ctime=1612193932)
# N-Z woothr XC561994.mp3 to big 29506616 os.stat_result(st_mode=33152, st_ino=59788, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=29506616, st_atime=1612193932, st_mtime=1600082648, st_ctime=1612193932)
# N-Z woothr XC565118.mp3 to big 1251425 os.stat_result(st_mode=33152, st_ino=59792, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1251425, st_atime=1612193933, st_mtime=1600082652, st_ctime=1612193933)
# N-Z woothr XC569566.mp3 to big 4611802 os.stat_result(st_mode=33152, st_ino=59796, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=4611802, st_atime=1612193933, st_mtime=1600082652, st_ctime=1612193933)
# N-Z woothr XC572257.mp3 to big 1208950 os.stat_result(st_mode=33152, st_ino=59805, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1208950, st_atime=1612193934, st_mtime=1600082652, st_ctime=1612193934)
# N-Z woothr XC580620.mp3 to big 34906031 os.stat_result(st_mode=33152, st_ino=59822, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=34906031, st_atime=1612193934, st_mtime=1600082654, st_ctime=1612193934)
# N-Z woothr XC580923.mp3 to big 18039118 os.stat_result(st_mode=33152, st_ino=59825, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=18039118, st_atime=1612193935, st_mtime=1600082656, st_ctime=1612193935)
# N-Z woothr XC70687.mp3 to big 1759279 os.stat_result(st_mode=33152, st_ino=59827, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1759279, st_atime=1612193936, st_mtime=1600082660, st_ctime=1612193936)
# N-Z woothr XC70689.mp3 to big 1609246 os.stat_result(st_mode=33152, st_ino=59832, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1609246, st_atime=1612193936, st_mtime=1600082660, st_ctime=1612193936)
# N-Z woothr XC70690.mp3 to big 2779554 os.stat_result(st_mode=33152, st_ino=59834, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=2779554, st_atime=1612193936, st_mtime=1600082660, st_ctime=1612193936)
# N-Z woothr XC70691.mp3 to big 1257401 os.stat_result(st_mode=33152, st_ino=59836, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1257401, st_atime=1612193936, st_mtime=1600082660, st_ctime=1612193936)
# N-Z woothr XC70692.mp3 to big 1288391 os.stat_result(st_mode=33152, st_ino=59838, st_dev=49, st_nlink=1, st_uid=0, st_gid=0, st_size=1288391, st_atime=1612193936, st_mtime=1600082660, st_ctime=1612193936)
# array([    0,     1,     2, ..., 11524, 11525, 11526])

# %% [markdown]
# # Define multi class model

# %%
def get_y_fn(x):
  #y = str(x).split(".")[0].split('_')[-2]
  y = df[df["filename"] == x]["ebird_code"].values[0]
  return y

# FOLD = 0
# val_index = train_folds[FOLD]
# FOLD = str(FOLD)
# val_index

# %%
#train_folds[0].shape

# %% [markdown]
# ## define mixup

# %%
# !git clone https://github.com/nestordemeure/ManifoldMixupV2.git
# Out:
# fatal: destination path 'ManifoldMixupV2' already exists and is not an empty directory.

# %%
# %run /content/ManifoldMixupV2/manifold_mixup.py
OutputMixup()
# Out:
# OutputMixup

# %% [markdown]
# ## Define db and dls

# %%
def random_power(images, power = 1.5, c= 0.7):
    images = images**(torch.rand(1, device="cuda:0")*power + c)
    #print(images.dtype)
    return images

def normalize_mel(melspec):
    melspec -= melspec.min()
    melspec /= melspec.max()
    #print(melspec)
    return melspec

def normalize_image(melspec):
    #normalize
    m = melspec.min(2, keepdim=True)[0].min(3, keepdim=True)[0]
    melspec -= m
    s = melspec.max(2, keepdim=True)[0].max(3, keepdim=True)[0]
    #s = torch.maximum(s, torch.ones_like(s)*1e-7)
    melspec /= s
    #print(melspec)
    return melspec

def normalize_channel(melspec):
    #normalize
    m = melspec.min(2, keepdim=True)[0].min(3, keepdim=True)[0]
    melspec -= m
    s = melspec.max(2, keepdim=True)[0].max(3, keepdim=True)[0]
    #s = torch.maximum(s, torch.ones_like(s)*1e-7)
    melspec /= s
    #print(melspec)
    return melspec

class Normalize_channel_1(Transform):
  def __init__(self):
    split_idx = None
  def encodes(self, melspec: AudioSpectrogram) -> AudioSpectrogram:
    return normalize_image(melspec)

class Normalize_channel_2(Transform):
  def __init__(self):
    split_idx = None
  def encodes(self, melspec: AudioSpectrogram) -> AudioSpectrogram:
    return normalize_image(melspec)

class Normalize_channel_3(Transform):
  def __init__(self):
    split_idx = None
  def encodes(self, melspec: AudioSpectrogram) -> AudioSpectrogram:
    return normalize_image(melspec)

class PowerSpec(Transform):
    """
    Transform для возведения спектрограммы в степень.
    """
    def __init__(self, power = 2, c = 0.7):
      self.power = power
      self.c = c
      split_idx = None
    def encodes(self, melspec: AudioSpectrogram) -> AudioSpectrogram:
      mel = random_power(melspec, self.power, self.c)
      #print(melspec, mel, mel.size())
      return mel

class LowerUpperFreq(Transform):
    """
    Transform для понижения верхних частот.
    """
    def __init__(self, cfg):
      self.cfg = cfg
      split_idx = None
    def encodes(self, images: AudioSpectrogram) -> AudioSpectrogram:
      if torch.rand(1)<0.5:
        images = images - images.min(dim =2, keepdim=True)[0]
        r = random.randint(self.cfg.n_mels//2,self.cfg.n_mels)
        x = random.random()/2
        #print(r, x, torch.zeros(self.cfg.n_mels-r)-x+1)
        pink_noise = torch.cat((1-torch.arange(r, device="cuda:0")*x/r,
                                               torch.ones(self.cfg.n_mels-r, device="cuda:0")-x)).T

        #pink_noise = np.array([np.concatenate((1-np.arange(r)*x/r,np.zeros(self.hp.n_mels-r)-x+1))]).T
        #print(images.size(), pink_noise.size(), pink_noise)   
        #print(pink_noise, images)
        images = images.movedim(3,2)       

        images = images*pink_noise
        #images = images/(images.max(dim =2, keepdim=True)[0]
        images = images.movedim(3,2)
        #print(images.shape, images)
      return images

class RowNoise(Transform):
    """
    Transform полосового шума.
    """
    def __init__(self, level_noise, cfg):
      self.cfg = cfg
      self.level_noise = level_noise
      self.split_idx = 0
    def encodes(self, images: AudioSpectrogram) -> AudioSpectrogram:
      if torch.rand(1)<0.9:
        a = int(torch.rand(1, device="cuda:0") * self.cfg.n_mels//2)
        b =  int(torch.min(torch.rand(1, device="cuda:0") * self.cfg.n_mels, a+20))
        images[a:b,:] = images[a:b,:] + (torch.rand((b-a,images.size()[-1]), device="cuda:0")+9.0) * 0.05 * images.mean() * self.level_noise  * (torch.rand(1, device="cuda:0") + 0.3)

        
      return images

# %%
class PinkNoise(Transform):
    """
    Transform для розового шума.
    """
    def __init__(self, level_noise, cfg):
      self.level_noise = level_noise
      self.cfg = cfg
      self.split_idx = 0
    def encodes(self, images: AudioSpectrogram) -> AudioSpectrogram:
      if torch.rand(1)<0.9:
        r = random.randint(1, self.cfg.n_mels)
         #print(r, x, torch.zeros(self.cfg.n_mels-r)-x+1)
        pink_noise = torch.cat((1-torch.arange(r, device="cuda:0")/r,
                                               torch.zeros(self.cfg.n_mels-r, device="cuda:0"))).T

        #pink_noise = np.array([np.concatenate((1-np.arange(r)*x/r,np.zeros(self.hp.n_mels-r)-x+1))]).T
        #print(images.size(), pink_noise.size(), pink_noise)   
       
        images = images + (torch.rand((self.cfg.n_mels,images.size()[-1]), device="cuda:0")+9.0) * 2  * images.mean() * self.level_noise * (torch.rand(1, device="cuda:0") + 0.3)
        #print(pink_noise, images)
        #print(images.shape, images)
      return images

class WhiteNoise(Transform):
    """
    Transform для розового шума.
    """
    def __init__(self, level_noise, cfg):
      self.level_noise = level_noise
      self.cfg = cfg
      self.split_idx = 0
    def encodes(self, images: AudioSpectrogram) -> AudioSpectrogram:
      if torch.rand(1)<0.9:
        images = images + (torch.rand((self.cfg.n_mels,images.size()[-1]), device="cuda:0")+9.0) * images.mean() * self.level_noise * (torch.rand(1, device="cuda:0") + 0.3)
        #print(images.shape, images)
      return images

# %%
class Mono2Color(Transform):
    """
    Transform для создания цветной картинки.
    """
    def __init__(self):
      split_idx = None
    def encodes(self, images: AudioSpectrogram) -> AudioSpectrogram:
      delta = torchaudio.functional.compute_deltas(images)
      delta2 = torchaudio.functional.compute_deltas(delta)
      colored_image = torch.cat((images, delta, delta2), dim=1)
      #print(colored_image.shape)
      return colored_image

class Mask(Transform):
    """
    Transform для рандомизации MaskFreq и MaskTime.
    """
    def __init__(self):
      split_idx = None
    def encodes(self, images: AudioSpectrogram) -> AudioSpectrogram:
      rnd = torch.rand(1)
      #print(images[0].shape, images.dtype, rnd, int(rnd*8))
      #if isinstance(images, AudioSpectrogram): 
      if rnd < 0.25:
        images.data = MaskFreq(num_masks=int(rnd*8), size=20)(images) 
        images.data = MaskTime(num_masks=int(rnd*8), size=16)(images)         
      elif rnd < 0.5:
        images.data = MaskFreq(num_masks=int(rnd*4), size=20)(images)
      elif rnd < 0.75:
        images.data = MaskTime(num_masks=int(rnd*4), size=16)(images)

      return images

# %%
def get_y_fn(x):
  #y = str(x).split(".")[0].split('_')[-2]
  try: 
    #y = df[df["filename"] == x.stem + ".mp3"]["ebird_code"].values[0]
    y = x.parent.name
  except: 
    print(x, "нет")
    y = None
  #print(y)
  return y

cfg = AudioConfig.BasicMelSpectrogram(
        mel=True,
  #      to_db = False
        # n_fft=1024,
        n_mels=384,
        hop_length=292,
       # n_fft = 892, 
        #hop_length=245, 
        #n_mels = 224,
      #  normalized=True
     #   power=3 # неплохо, возможно стоит дошибить рандомный power
   )

item_tfms = [Resample(28000),
             ResizeSignal(8000, pad_mode=AudioPadType.Repeat), 
            AddNoise(noise_level=0.05, color=NoiseColor.Pink),
            AddNoise(noise_level=0.05, color=NoiseColor.White),
           ]
batch_tfms = [ AudioToSpec.from_cfg(cfg), 
       #       Normalize_channel(),
       #       PowerSpec(), # увеличение контрастности
       #       TAmplitudeToDB(),
              Normalize_channel_1(),
    #          PowerSpec(1.5, 0.7),
              WhiteNoise(0.005, cfg),
              PinkNoise(0.005, cfg),
       #       RowNoise(0.025, cfg),
              LowerUpperFreq(cfg),
              Normalize_channel_2(),
              PowerSpec(2, 0.7), # увеличение контрастности
      #        Normalize_channel_3(),
              SGRoll(),
              Mask(),
           #   Mono2Color()
         #     Normalize(ch_mean, ch_std, axes=(0, 1, 3)),
              ]
AddNoise.split_idx = 0
Mask.split_idx = 0

SGRoll.split_idx = 0

auds = DataBlock(blocks = (AudioBlock, CategoryBlock),  
                 get_items=get_audio_files,
                 item_tfms = item_tfms,
                 splitter = IndexSplitter(val_index), 
                 #splitter = RandomSplitter(),
                 get_y=get_y_fn,
                 batch_tfms = batch_tfms

                                  )
print(auds.summary(TRAIN_AUDIO_ROOT))
dls = auds.dataloaders(TRAIN_AUDIO_ROOT, bs=12, verbose=True, before_batch = batch_tfms, 
                       num_workers=4
                       #, shuffle=True
                      )
# Out:
# /usr/local/lib/python3.6/dist-packages/torchaudio/functional.py:318: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (384) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   "At least one mel filterbank has all zero values. "
# Setting-up type transforms pipelines
# Collecting items from /content/drive/MyDrive/Colab Notebooks/RainForestAudio/other_data
# Found 11579 items
# 2 datasets of sizes 9263,2316
# Setting up Pipeline: partial
# Setting up Pipeline: get_y_fn -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#
# Building one sample
#   Pipeline: partial
#     starting from
#       /content/drive/MyDrive/Colab Notebooks/RainForestAudio/other_data/A-M/amecro/XC287517.mp3
#     applying partial gives
#       AudioTensor of size 2x1087488
#   Pipeline: get_y_fn -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#     starting from
#       /content/drive/MyDrive/Colab Notebooks/RainForestAudio/other_data/A-M/amecro/XC287517.mp3
#     applying get_y_fn gives
#       amecro
#     applying Categorize -- {'vocab': None, 'sort': True, 'add_na': False} gives
#       TensorCategory(1)
#
# Final sample: (AudioTensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  2.7125e-04,
#           2.4065e-04,  8.4985e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -9.6783e-05,
#          -2.1681e-06, -2.8065e-04]]), TensorCategory(1))
#
#
# Collecting items from /content/drive/MyDrive/Colab Notebooks/RainForestAudio/other_data
# Found 11579 items
# 2 datasets of sizes 9263,2316
# Setting up Pipeline: partial
# Setting up Pipeline: get_y_fn -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
# Setting up after_item: Pipeline: Resample -> DownmixMono -> ResizeSignal -> AddNoise -> ToTensor
# Setting up before_batch: Pipeline:
# Setting up after_batch: Pipeline: AudioToSpec -> Normalize_channel_1 -> WhiteNoise -> PinkNoise -> LowerUpperFreq -> Normalize_channel_2 -> PowerSpec -> SGRoll -> Mask -> IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#
# Building one batch
# Applying item_tfms to the first sample:
#   Pipeline: Resample -> DownmixMono -> ResizeSignal -> AddNoise -> ToTensor
#     starting from
#       (AudioTensor of size 2x1087488, TensorCategory(1))
#     applying Resample gives
#       (AudioTensor of size 2x634368, TensorCategory(1))
#     applying DownmixMono gives
#       (AudioTensor of size 1x634368, TensorCategory(1))
#     applying ResizeSignal gives
#       (AudioTensor of size 1x224000, TensorCategory(1))
#     applying AddNoise gives
#       (AudioTensor of size 1x224000, TensorCategory(1))
#     applying ToTensor gives
#       (AudioTensor of size 1x224000, TensorCategory(1))
#
# Adding the next 3 samples
#
# No before_batch transform to apply
#
# Collating items in a batch
#
# Applying batch_tfms to the batch built
#   Pipeline: AudioToSpec -> Normalize_channel_1 -> WhiteNoise -> PinkNoise -> LowerUpperFreq -> Normalize_channel_2 -> PowerSpec -> SGRoll -> Mask -> IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#     starting from
#       (AudioTensor of size 4x1x224000, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying AudioToSpec gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying Normalize_channel_1 gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying WhiteNoise gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying PinkNoise gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying LowerUpperFreq gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying Normalize_channel_2 gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying PowerSpec gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying SGRoll gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying Mask gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
#     applying IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} gives
#       (AudioSpectrogram of size 4x1x384x768, TensorCategory([1, 1, 1, 1], device='cuda:0'))
# None
# Collecting items from /content/drive/MyDrive/Colab Notebooks/RainForestAudio/other_data
# Found 11579 items
# 2 datasets of sizes 9263,2316
# Setting up Pipeline: partial
# Setting up Pipeline: get_y_fn -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
# Setting up after_item: Pipeline: Resample -> DownmixMono -> ResizeSignal -> AddNoise -> ToTensor
# Setting up before_batch: Pipeline: AudioToSpec -> Normalize_channel_1 -> WhiteNoise -> PinkNoise -> LowerUpperFreq -> Normalize_channel_2 -> PowerSpec -> SGRoll -> Mask
# Setting up after_batch: Pipeline: AudioToSpec -> Normalize_channel_1 -> WhiteNoise -> PinkNoise -> LowerUpperFreq -> Normalize_channel_2 -> PowerSpec -> SGRoll -> Mask -> IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}

# %%
def _one_sample_positive_class_precisions(scores, truth):
    num_classes = scores.shape[0]
    pos_class_indices = np.flatnonzero(truth > 0)

    if not len(pos_class_indices):
        return pos_class_indices, np.zeros(0)

    retrieved_classes = np.argsort(scores)[::-1]

    class_rankings = np.zeros(num_classes, dtype=np.int)
    class_rankings[retrieved_classes] = range(num_classes)

    retrieved_class_true = np.zeros(num_classes, dtype=np.bool)
    retrieved_class_true[class_rankings[pos_class_indices]] = True

    retrieved_cumulative_hits = np.cumsum(retrieved_class_true)

    precision_at_hits = (
            retrieved_cumulative_hits[class_rankings[pos_class_indices]] /
            (1 + class_rankings[pos_class_indices].astype(np.float)))
    return pos_class_indices, precision_at_hits

def lwlrap(scores, truth):
    #print(truth.shape, scores.shape)
    num_samples, num_classes = scores.shape
    scores = scores.cpu().numpy()
    gt = np.zeros((num_samples, num_classes))
    for n, i in enumerate(truth.cpu().numpy().astype(int)):
      gt[n, i] = 1
    assert gt.shape == scores.shape
    
    precisions_for_samples_by_classes = np.zeros((num_samples, num_classes))
    for sample_num in range(num_samples):
        pos_class_indices, precision_at_hits = _one_sample_positive_class_precisions(scores[sample_num, :], gt[sample_num, :])
        precisions_for_samples_by_classes[sample_num, pos_class_indices] = precision_at_hits

    labels_per_class = np.sum(gt > 0, axis=0)
    weight_per_class = labels_per_class / float(np.sum(labels_per_class))

    per_class_lwlrap = (np.sum(precisions_for_samples_by_classes, axis=0) /
                        np.maximum(1, labels_per_class))
    #return per_class_lwlrap, weight_per_class
    return (per_class_lwlrap * weight_per_class).sum()

# %%
from efficientnet_pytorch import EfficientNet
from timm import create_model
# from https://colab.research.google.com/github/muellerzr/Practical-Deep-Learning-for-Coders-2.0/blob/master/Computer%20Vision/05_EfficientNet_and_Custom_Weights.ipynb#scrollTo=VXPjDVUlJgCU

# %%
def init_layer(layer):
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, "bias"):
        if layer.bias is not None:
            layer.bias.data.fill_(0.)


def init_bn(bn):
    bn.bias.data.fill_(0.)
    bn.weight.data.fill_(1.0)


def interpolate(x: torch.Tensor, ratio: int):
    """Interpolate data in time domain. This is used to compensate the
    resolution reduction in downsampling of a CNN.

    Args:
      x: (batch_size, time_steps, classes_num)
      ratio: int, ratio to interpolate
    Returns:
      upsampled: (batch_size, time_steps * ratio, classes_num)
    """
    (batch_size, time_steps, classes_num) = x.shape
    upsampled = x[:, :, None, :].repeat(1, 1, ratio, 1)
    upsampled = upsampled.reshape(batch_size, time_steps * ratio, classes_num)
    return upsampled


def pad_framewise_output(framewise_output: torch.Tensor, frames_num: int):
    """Pad framewise_output to the same length as input frames. The pad value
    is the same as the value of the last frame.
    Args:
      framewise_output: (batch_size, frames_num, classes_num)
      frames_num: int, number of frames to pad
    Outputs:
      output: (batch_size, frames_num, classes_num)
    """
    pad = framewise_output[:, -1:, :].repeat(
        1, frames_num - framewise_output.shape[1], 1)
    """tensor for padding"""

    output = torch.cat((framewise_output, pad), dim=1)
    """(batch_size, frames_num, classes_num)"""

    return output


class ConvBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int):
        super().__init__()

        self.conv1 = nn.Conv2d(
            in_channels=in_channels,
            out_channels=out_channels,
            kernel_size=(3, 3),
            stride=(1, 1),
            padding=(1, 1),
            bias=False)

        self.conv2 = nn.Conv2d(
            in_channels=out_channels,
            out_channels=out_channels,
            kernel_size=(3, 3),
            stride=(1, 1),
            padding=(1, 1),
            bias=False)

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.init_weight()

    def init_weight(self):
        init_layer(self.conv1)
        init_layer(self.conv2)
        init_bn(self.bn1)
        init_bn(self.bn2)

    def forward(self, input, pool_size=(2, 2), pool_type='avg'):

        x = input
        x = F.relu_(self.bn1(self.conv1(x)))
        x = F.relu_(self.bn2(self.conv2(x)))
        if pool_type == 'max':
            x = F.max_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg':
            x = F.avg_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg+max':
            x1 = F.avg_pool2d(x, kernel_size=pool_size)
            x2 = F.max_pool2d(x, kernel_size=pool_size)
            x = x1 + x2
        else:
            raise Exception('Incorrect argument!')

        return x


class AttBlock(nn.Module):
    def __init__(self,
                 in_features: int,
                 out_features: int,
                 activation="linear",
                 temperature=1.0):
        super().__init__()

        self.activation = activation
        self.temperature = temperature
        self.att = nn.Conv1d(
            in_channels=in_features,
            out_channels=out_features,
            kernel_size=1,
            stride=1,
            padding=0,
            bias=True)
        self.cla = nn.Conv1d(
            in_channels=in_features,
            out_channels=out_features,
            kernel_size=1,
            stride=1,
            padding=0,
            bias=True)

        self.bn_att = nn.BatchNorm1d(out_features)
        self.init_weights()
        self.in_channels=in_features
        self.out_channels=out_features

    def init_weights(self):
        init_layer(self.att)
        init_layer(self.cla)
        init_bn(self.bn_att)

    def forward(self, x):
        # x: (n_samples, n_in, n_time)
        #print(x.size())
        x = x.view(-1, self.in_channels, 1)
        
        #print(self.att(x).size())
        norm_att = torch.softmax(torch.tanh(self.att(x)), dim=-1)
        cla = self.nonlinear_transform(self.cla(x))
        x = torch.sum(norm_att * cla, dim=2)

        #return x, norm_att, cla
        #print(x)
        return x

    def nonlinear_transform(self, x):
        if self.activation == 'linear':
            return x
        elif self.activation == 'sigmoid':
            return torch.sigmoid(x)

# %%
dls.c
# Out:
# 64

# %%
def create_timm_body(arch:str, pretrained=True, cut=None):
  model = create_model(arch, pretrained=pretrained, in_chans=3)
  if cut is None:
    ll = list(enumerate(model.children()))
    cut = next(i for i,o in reversed(ll) if has_pool_type(o))
  if isinstance(cut, int): return nn.Sequential(*list(model.children())[:cut])
  elif callable(cut): return cut(model)
  else: raise NamedError("cut must be either integer or function")
body = create_timm_body('tf_efficientnet_b4_ns', pretrained=True)


head = create_head(num_features_model(nn.Sequential(*body.children())) * (2), dls.c, ps=0.4, lin_ftrs=[512])
head.__setitem__(8, AttBlock(512, dls.c))
head.__setitem__(5, nn.SiLU(inplace=True))
model = nn.Sequential(body, head)

apply_init(model[1], nn.init.kaiming_normal_)
len(model)
# Out:
# 2

# %%
model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2dSame(1, 48, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU(inplace=True)
#     (3): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (bn1): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pw): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn2): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): Identity()
#         )
#         (1): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pw): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn2): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): Identity()
#         )
#       )
#       (1): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(144, 144, kernel_size=(3, 3), stride=(2, 2), groups=144, bias=False)
#           (bn2): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (bn2): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (bn2): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (bn2): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(192, 192, kernel_size=(5, 5), stride=(2, 2), groups=192, bias=False)
#           (bn2): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(192, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#           (bn2): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#           (bn2): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#           (bn2): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(336, 336, kernel_size=(3, 3), stride=(2, 2), groups=336, bias=False)
#           (bn2): BatchNorm2d(336, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(336, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): InvertedResidual(
#           (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): InvertedResidual(
#           (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#           (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): InvertedResidual(
#           (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): InvertedResidual(
#           (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2dSame(960, 960, kernel_size=(5, 5), stride=(2, 2), groups=960, bias=False)
#           (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(960, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (6): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (7): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(272, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): Sequential(
#         (0): InvertedResidual(
#           (conv_pw): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(1632, 1632, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1632, bias=False)
#           (bn2): BatchNorm2d(1632, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(1632, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): InvertedResidual(
#           (conv_pw): Conv2d(448, 2688, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(2688, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act1): SiLU(inplace=True)
#           (conv_dw): Conv2d(2688, 2688, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2688, bias=False)
#           (bn2): BatchNorm2d(2688, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU(inplace=True)
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(2688, 112, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(112, 2688, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_pwl): Conv2d(2688, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): Conv2d(448, 1792, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (5): BatchNorm2d(1792, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (6): SiLU(inplace=True)
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten(full=False)
#     (2): BatchNorm1d(3584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=3584, out_features=512, bias=False)
#     (5): SiLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.4, inplace=False)
#     (8): AttBlock(
#       (att): Conv1d(512, 64, kernel_size=(1,), stride=(1,))
#       (cla): Conv1d(512, 64, kernel_size=(1,), stride=(1,))
#       (bn_att): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
learn = Learner(dls,  model,
           # n_in=1, #<- Only audio specific modification here
        #    loss_func=LabelSmoothingCrossEntropyFlat(),
            cbs = OutputMixup(alpha=0.4),
            metrics=[accuracy, lwlrap],
            )
#learn.to_fp16()
learn.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %%
dls.show_batch(), dls.vocab
# Out:
# (None,
#  ['aldfly', 'amecro', 'amered', 'amerob', 'astfly', 'barswa', 'bewwre', 'bkcchi', 'bkhgro', 'blujay', 'bnhcow', 'brncre', 'buggna', 'bulori', 'cangoo', 'carwre', 'chispa', 'comrav', 'comred', 'comter', 'comyel', 'daejun', 'easmea', 'eastow', 'eucdov', 'eursta', 'gnwtea', 'grhowl', 'grtgra', 'grycat', 'herthr', 'horlar', 'houfin', 'houspa', 'houwre', 'indbun', 'lesgol', 'mallar3', 'marwre', 'mouchi', 'norcar', 'norfli', 'normoc', 'norwat', 'orcwar', 'osprey', 'redcro', 'rewbla', 'ruckin', 'savspa', 'sonspa', 'spotow', 'swathr', 'tuftit', 'warvir', 'wesmea', 'wewpew', 'whbnut', 'whcspa', 'whtspa', 'wilfly', 'winwre3', 'wlswar', 'woothr'])

# %%
CUDA_LAUNCH_BLOCKING=1
#learn.lr_find()

# %%
FOLD = "0"
EXP_NAME = "xeno_canto_b4_fold" + FOLD 
SUFFIX ="step1"
learn.freeze()
learn.fit(1, 1e-3)
learn.unfreeze()
learn.fit_one_cycle(25, 1e-3, wd=1e-2, div=10, pct_start=0.3,
                    cbs=[SaveModelCallback(fname = f'{EXP_NAME}_{SUFFIX}', with_opt=True)])
# Out:
# Output mixup: the loss function is now properly wrapped.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.785094</td>
#       <td>4.852626</td>
#       <td>0.176166</td>
#       <td>0.295908</td>
#       <td>22:04</td>
#     </tr>
#   </tbody>
# </table>
# Output mixup: the loss function is now properly wrapped.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [5/25 1:38:56<6:35:44]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.235501</td>
#       <td>3.163899</td>
#       <td>0.340242</td>
#       <td>0.468338</td>
#       <td>19:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.940609</td>
#       <td>2.471475</td>
#       <td>0.393782</td>
#       <td>0.518342</td>
#       <td>19:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.855371</td>
#       <td>2.866437</td>
#       <td>0.385579</td>
#       <td>0.516668</td>
#       <td>19:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.716189</td>
#       <td>2.424014</td>
#       <td>0.420121</td>
#       <td>0.546181</td>
#       <td>19:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.595556</td>
#       <td>2.263083</td>
#       <td>0.474957</td>
#       <td>0.585522</td>
#       <td>20:09</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='144' class='' max='771' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 5 with valid_loss value: 2.037207841873169.
# Better model found at epoch 6 with valid_loss value: 1.9252861738204956.
# Better model found at epoch 7 with valid_loss value: 1.9170821905136108.
# Better model found at epoch 8 with valid_loss value: 1.7370116710662842.
# Better model found at epoch 9 with valid_loss value: 1.7136977910995483.
# Better model found at epoch 10 with valid_loss value: 1.6096972227096558.
# Better model found at epoch 11 with valid_loss value: 1.5234959125518799.
# Better model found at epoch 12 with valid_loss value: 1.5076429843902588.
# Better model found at epoch 13 with valid_loss value: 1.309531569480896.
# Better model found at epoch 15 with valid_loss value: 1.2449486255645752.
# Better model found at epoch 16 with valid_loss value: 1.2286986112594604.
# Better model found at epoch 18 with valid_loss value: 1.1656948328018188.
# Better model found at epoch 20 with valid_loss value: 1.1499046087265015.
# Better model found at epoch 21 with valid_loss value: 1.1268285512924194.
# Better model found at epoch 24 with valid_loss value: 1.0988233089447021.

# %%
wdc wc
# Out:
#   File "<ipython-input-123-c3a5d3c3f011>", line 1
#     wdc wc
#          ^
# SyntaxError: invalid syntax

# %%
SUFFIX ="step2"
#learn.load(EXP_NAME+"_step1")
learn.fit_one_cycle(25, 1e-3/5, wd=1e-2, div=10, pct_start=0.3,
                    cbs=[SaveModelCallback(fname = f'{EXP_NAME}_{SUFFIX}', with_opt=True)]
                    )
# Out:
# Output mixup: the loss function is now properly wrapped.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [5/25 1:45:01<7:00:04]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.096470</td>
#       <td>1.136564</td>
#       <td>0.747841</td>
#       <td>0.811054</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.081484</td>
#       <td>1.145626</td>
#       <td>0.745250</td>
#       <td>0.810654</td>
#       <td>19:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.122395</td>
#       <td>1.201045</td>
#       <td>0.743092</td>
#       <td>0.807967</td>
#       <td>20:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.075142</td>
#       <td>1.195174</td>
#       <td>0.733592</td>
#       <td>0.802431</td>
#       <td>21:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.091484</td>
#       <td>1.184642</td>
#       <td>0.733592</td>
#       <td>0.804357</td>
#       <td>22:12</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='186' class='' max='771' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       24.12% [186/771 04:33<14:19 1.0776]
#     </div>
# Better model found at epoch 0 with valid_loss value: 1.1365638971328735.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.096470</td>
#       <td>1.136564</td>
#       <td>0.747841</td>
#       <td>0.811054</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.081484</td>
#       <td>1.145626</td>
#       <td>0.745250</td>
#       <td>0.810654</td>
#       <td>19:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.122395</td>
#       <td>1.201045</td>
#       <td>0.743092</td>
#       <td>0.807967</td>
#       <td>20:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.075142</td>
#       <td>1.195174</td>
#       <td>0.733592</td>
#       <td>0.802431</td>
#       <td>21:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.091484</td>
#       <td>1.184642</td>
#       <td>0.733592</td>
#       <td>0.804357</td>
#       <td>22:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.137155</td>
#       <td>1.245823</td>
#       <td>0.721071</td>
#       <td>0.791860</td>
#       <td>23:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.118002</td>
#       <td>1.151297</td>
#       <td>0.734456</td>
#       <td>0.806701</td>
#       <td>21:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.067497</td>
#       <td>1.214655</td>
#       <td>0.737478</td>
#       <td>0.800894</td>
#       <td>22:34</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.091951</td>
#       <td>1.218567</td>
#       <td>0.730138</td>
#       <td>0.797538</td>
#       <td>21:58</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.056510</td>
#       <td>03:16</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _do_epoch(self)
#     190     def _do_epoch(self):
# --> 191         self._do_epoch_train()
#     192         self._do_epoch_validate()
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _do_epoch_train(self)
#     182         self.dl = self.dls.train
# --> 183         self._with_events(self.all_batches, 'train', CancelTrainException)
#     184
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in all_batches(self)
#     160         self.n_iter = len(self.dl)
# --> 161         for o in enumerate(self.dl): self.one_batch(*o)
#     162
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in one_batch(self, i, b)
#     178         self._split(b)
# --> 179         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     180
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _do_one_batch(self)
#     169         self('before_backward')
# --> 170         self._backward()
#     171         self('after_backward')
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _backward(self)
#     151     def _step(self): self.opt.step()
# --> 152     def _backward(self): self.loss.backward()
#     153
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
# --> 220                 create_graph=create_graph)
#     221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#
# /usr/local/lib/python3.6/dist-packages/torch/overrides.py in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1062         # implementations can do equality/identity comparisons.
# -> 1063         result = overloaded_arg.__torch_function__(public_api, types, args, kwargs)
#    1064
#
# /usr/local/lib/python3.6/dist-packages/fastai/torch_core.py in __torch_function__(self, func, types, args, kwargs)
#     318 #         with torch._C.DisableTorchFunction(): ret = _convert(func(*args, **(kwargs or {})), self.__class__)
# --> 319         ret = super().__torch_function__(func, types, args=args, kwargs=kwargs)
#     320         if isinstance(ret, TensorBase): ret.set_meta(self, as_copy=True)
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in __torch_function__(cls, func, types, args, kwargs)
#     994         with _C.DisableTorchFunction():
# --> 995             ret = func(*args, **kwargs)
#     996             return _convert(ret, cls)
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-124-3969d02a3caa> in <module>
#       2 #learn.load(EXP_NAME+"_step1")
#       3 learn.fit_one_cycle(25, 1e-3/5, wd=1e-2, div=10, pct_start=0.3,
# ----> 4                     cbs=[SaveModelCallback(fname = f'{EXP_NAME}_{SUFFIX}', with_opt=True)]
#       5                     )
#
# /usr/local/lib/python3.6/dist-packages/fastai/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt)
#     110     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     111               'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 112     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#     113
#     114 # Cell
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     204             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     205             self.n_epoch = n_epoch
# --> 206             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     207
#     208     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _do_fit(self)
#     195         for epoch in range(self.n_epoch):
#     196             self.epoch=epoch
# --> 197             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     198
#     199     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
# --> 157         finally:   self(f'after_{event_type}')        ;final()
#     158
#     159     def all_batches(self):
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in __call__(self, event_name)
#     131     def ordered_cbs(self, event): return [cb for cb in sort_by_run(self.cbs) if hasattr(cb, event)]
#     132
# --> 133     def __call__(self, event_name): L(event_name).map(self._call_one)
#     134
#     135     def _call_one(self, event_name):
#
# /usr/local/lib/python3.6/dist-packages/fastcore/foundation.py in map(self, f, gen, *args, **kwargs)
#     152     def range(cls, a, b=None, step=None): return cls(range_of(a, b=b, step=step))
#     153
# --> 154     def map(self, f, *args, gen=False, **kwargs): return self._new(map_ex(self, f, *args, gen=gen, **kwargs))
#     155     def argwhere(self, f, negate=False, **kwargs): return self._new(argwhere(self, f, negate, **kwargs))
#     156     def filter(self, f=noop, negate=False, gen=False, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/fastcore/basics.py in map_ex(iterable, f, gen, *args, **kwargs)
#     639     res = map(g, iterable)
#     640     if gen: return res
# --> 641     return list(res)
#     642
#     643 # Cell
#
# /usr/local/lib/python3.6/dist-packages/fastcore/basics.py in __call__(self, *args, **kwargs)
#     629             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     630         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 631         return self.func(*fargs, **kwargs)
#     632
#     633 # Cell
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in _call_one(self, event_name)
#     135     def _call_one(self, event_name):
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#     139     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in <listcomp>(.0)
#     135     def _call_one(self, event_name):
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#     139     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# /usr/local/lib/python3.6/dist-packages/fastai/callback/core.py in __call__(self, event_name)
#      42                (self.run_valid and not getattr(self, 'training', False)))
#      43         res = None
# ---> 44         if self.run and _run: res = getattr(self, event_name, noop)()
#      45         if event_name=='after_fit': self.run=True #Reset self.run to True at each end of fit
#      46         return res
#
# /usr/local/lib/python3.6/dist-packages/fastai/callback/tracker.py in after_epoch(self)
#      78         if self.every_epoch: self._save(f'{self.fname}_{self.epoch}')
#      79         else: #every improvement
# ---> 80             super().after_epoch()
#      81             if self.new_best:
#      82                 print(f'Better model found at epoch {self.epoch} with {self.monitor} value: {self.best}.')
#
# /usr/local/lib/python3.6/dist-packages/fastai/callback/tracker.py in after_epoch(self)
#      37     def after_epoch(self):
#      38         "Compare the last value to the best up to now"
# ---> 39         val = self.recorder.values[-1][self.idx]
#      40         if self.comp(val - self.min_delta, self.best): self.best,self.new_best = val,True
#      41         else: self.new_best = False
#
# /usr/local/lib/python3.6/dist-packages/fastcore/foundation.py in __getitem__(self, idx)
#     109     def _xtra(self): return None
#     110     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
# --> 111     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     112     def copy(self): return self._new(self.items.copy())
#     113
#
# /usr/local/lib/python3.6/dist-packages/fastcore/foundation.py in _get(self, i)
#     113
#     114     def _get(self, i):
# --> 115         if is_indexer(i) or isinstance(i,slice): return getattr(self.items,'iloc',self.items)[i]
#     116         i = mask2idxs(i)
#     117         return (self.items.iloc[list(i)] if hasattr(self.items,'iloc')
#
# IndexError: list index out of range

# %%
SUFFIX ="step3"
#learn.load(EXP_NAME+"_step2")
learn.to_fp16()
learn.fit_one_cycle(25, 1e-3/8, wd=1e-2, div=10, pct_start=0.3,
                    cbs=[SaveModelCallback(fname = f'{EXP_NAME}_{SUFFIX}', with_opt=True)]
                    )

# %% [markdown]
# ## confusion matrix

# %%
# interp = ClassificationInterpretation.from_learner(learn)
# interp.plot_confusion_matrix()

# %% [markdown]
# # Predict all classes

# %%
learn.load("b3_fold"+FOLD+"_step2", with_opt=False)
learn.remove_cbs(OutputMixup)
learn.cbs

# %%
# !ln -s drive/MyDrive/Colab\ Notebooks/RainForestAudio/data/ol_samples.tar.gz ol_samples.tar.gz  
# !ln -s drive/MyDrive/Colab\ Notebooks/RainForestAudio/data/val  val

# %%
TEST_SAMPLES_AUDIO_ROOT = Path("/content/samples")

#!ln -s drive/MyDrive/Colab\ Notebooks/RainForestAudio/data/val/ /content/val
VAL_AUDIO_ROOT = Path("/content/val")

test_ds = auds.new(VAL_AUDIO_ROOT)
test_dl = learn.dls.test_dl(get_audio_files(TEST_SAMPLES_AUDIO_ROOT))
#print(test_dl.summary(TEST_TARGET_AUDIO_ROOT))
#test_probas, *_ = learn.tta(dl=test_dl, n=2, use_max=True)
test_probas, *_ = learn.tta(dl=test_dl, n=4, use_max=False, beta=1/3)

# %%
result=[]
for probas, fname in zip(test_probas, test_dl.items):
  print(fname)
  result.append([fname.stem.split("_")[0], fname.stem.split("_")[1], probas.numpy()])
res = pd.DataFrame(result, columns =["recording_id", "part_id", "probas"])
res["part_id"] = res["part_id"].astype(int)
res.to_csv("all_class_pred_"+FOLD+".csv", columns =["recording_id", "part_id", "probas"])

# %%
subm = []
for n, row in res.sort_values(by="recording_id").groupby(by="recording_id"):
  a = np.stack(row["probas"].values)
  pred = np.concatenate([np.array(n).reshape(1),
                         np.array(dls.vocab[np.argmax(a.max(axis=0))]).reshape(1),
                         #np.where(a>0.7, a, 0).sum(axis=0)
                         a.max(axis=0)
                         ])
  subm.append(pred)
  #print(n)
  if n == "047a7c4bf":
    #print(row["probas"].max(axis=1))
    cls = np.stack(row["probas"].values).max(axis=0).argsort()
    #print(np.stack(row["probas"].values).argsort())
    #print(dls.vocab[cls[-1]], dls.vocab[cls[-2]], dls.vocab[cls[-3]])
#print(subm)
submission = pd.DataFrame(subm, columns=["recording_id"] + ["top_cat"] + ["s" + i for i in dls.vocab])
submission.head(10)

# %%
submission.drop(["top_cat"], axis=1, inplace=True)
submission.to_csv("subm_29_b3_fold_"+FOLD+".csv", columns=["recording_id"] + ["s" + str(i) for i in range(24)], index=False)

# %%
from sklearn.metrics import accuracy_score
gt=[]
pred=[]
for n, row in submission.iterrows():
  try:
    gr_tr = df[df["recording_id"] == row["recording_id"]]["species_id"].to_numpy()
    if gr_tr.shape[0] > 1:
      if int(row["top_cat"]) in gr_tr:
        gt.append(int(row["top_cat"]))
      else:
        gt.append(gr_tr[0])     
    else: 
      gt.append(gr_tr[0])
    pred.append(int(row["top_cat"]))
  except:
    pass
accuracy_score(gt,pred), len(gt)
#gt, pred

# %% [markdown]
# Усредненный сабмит

# %%
subm = []
#subm.append(submission.sort_values(by="recording_id").to_numpy()[:,1:].astype(float))
for i in range(4):
  s = pd.read_csv("subm_29_b3_fold_"+str(i)+".csv")
  subm.append(s.sort_values(by="recording_id").to_numpy()[:,1:])
subm = np.stack(subm)
subm.shape
fs = pd.DataFrame(np.concatenate([submission.sort_values(by="recording_id").to_numpy()[:,0].reshape(-1,1), subm.sum(axis=0)], axis=1),  columns=s.columns)
fs.head()

# %%
fs.to_csv("subm_29_b3_1.csv", index=False)

# %% [markdown]
# ## Вспомогательное

# %%
class MaskFreq(SpectrogramTransform):
    """Google SpecAugment frequency masking from https://arxiv.org/abs/1904.08779."""

    def __init__(self, num_masks=1, size=20, start=None, val=None):
        self.num_masks = num_masks
        self.size = size
        self.start = start
        self.val = val

    def encodes(self, sg: AudioSpectrogram) -> AudioSpectrogram:
        channel_mean = sg.contiguous().view(sg.size(0), -1).mean(-1)[:, None, None]
        mask_val = ifnone(self.val, channel_mean)
        if sg.ndim == 4:
          b, c, y, x = sg.shape
          # Position of the first mask
          start = ifnone(self.start, random.randint(0, y - self.size))
          for _ in range(self.num_masks):
              mask = torch.ones(self.size, x).cuda() * mask_val.cuda()
              mask = mask.view(b, c, self.size, x)
              #print("sg, mask:", sg.shape, mask.shape)
              if not 0 <= start <= y - self.size:
                  raise ValueError(
                      f"Start value '{start}' out of range for AudioSpectrogram of shape {sg.shape}"
                  )
              sg[:, :, start : start + self.size, :] = mask
              # Setting start position for next mask
              start = random.randint(0, y - self.size)
        else:
          c, y, x = sg.shape
          # Position of the first msk
          start = ifnone(self.start, random.randint(0, y - self.size))
          for _ in range(self.num_masks):
              mask = torch.ones(self.size, x) * mask_val
              if not 0 <= start <= y - self.size:
                  raise ValueError(
                      f"Start value '{start}' out of range for AudioSpectrogram of shape {sg.shape}"
                  )
              sg[:, start : start + self.size, :] = mask
              # Setting start position for next mask
              start = random.randint(0, y - self.size)
        return sg

# %%
# !git clone https://github.com/vlomme/Birdcall-Identification-competition.git
# Out:
# Cloning into 'Birdcall-Identification-competition'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 27 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
from google.colab import drive
drive.mount('/content/drive')# You must grant COLAB access to your Google Drive
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle --upgrade
# Out:
# Requirement already up-to-date: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.10)
# ...

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-016d0717-6459-4cb2-a877-f9e20077a198" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-016d0717-6459-4cb2-a877-f9e20077a198">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"nadyastrogankova","key":"98eac8a41c99ca40fbf883f1c775c3bd"}'}

# %%
# !mkdir ~/.kaggle

# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ...
# ref                                                    title                                                size  lastUpdated          downloadCount
# -----------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# gpreda/covid-world-vaccination-progress                COVID-19 World Vaccination Progress                  41KB  2021-02-01 08:48:19           5129
# ayushggarg/all-trumps-twitter-insults-20152021         All Trump's Twitter insults (2015-2021)             581KB  2021-01-20 16:51:05           1030
# sevgisarac/temperature-change                          Temperature change                                  778KB  2020-12-24 20:06:36           1124
# jorgesandoval/wind-power-generation                    Wind Power Generation Data                          245KB  2021-01-07 18:45:08            444
# ...

# %%
! kaggle competitions download -c 'birdsong-recognition'
# Out:
# ...
# ORANGE-7-CAP_20190606_093000.pt623.mp3.zip: Skipping, found more recently modified local copy (use --force to force download)
# BLKFR-10-CPL_20190611_093000.pt540.mp3.zip: Skipping, found more recently modified local copy (use --force to force download)
# XC141214.mp3: Skipping, found more recently modified local copy (use --force to force download)
# XC143748.mp3: Skipping, found more recently modified local copy (use --force to force download)
# XC131879.mp3: Skipping, found more recently modified local copy (use --force to force download)
# 429 - Too Many Requests

# %%
# !mv *mp3* train

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/RainForestAudio/other_data/train_mp3/* .

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/RainForestAudio/other_data/* .
# Out:
# cp: -r not specified; omitting directory '/content/drive/MyDrive/Colab Notebooks/RainForestAudio/other_data/train_mp3'

# %%
# !ln -s /content/drive/MyDrive/Colab\ Notebooks/RainForestAudio/other_data ./train

# %%
# !pip install efficientnet_pytorch
# Out:
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.0-cp36-none-any.whl size=16032 sha256=aa5035b24a6b4bb7fee676ee21ea7fa9a7dd84204ff15ed95a90e5a9ae2eb490
#   Stored in directory: /root/.cache/pip/wheels/e9/c6/e1/7a808b26406239712cfce4b5ceeb67d9513ae32aa4b31445c6
# Successfully built efficientnet-pytorch
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %cd /content/Birdcall-Identification-competition/
# %run train.py -r p
# Out:
# /content/Birdcall-Identification-competition
# 0it [00:00, ?it/s]
# Training dataset created / Тренировочный датасет создан

# %%
# %cd /content/Birdcall-Identification-competition/
# %run train.py -r t
# Out:
# /content/Birdcall-Identification-competition
# ['resnet50', 'efficientnet-b0', 'efficientnet-b0', 'efficientnet-b0', 'efficientnet-b0', 'resnet50']
#  ['']
#  [265, 265, 265, 265, 150, 265]
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
#                file    bird                           labels_bg
# 0      XC554809.mp3  aldfly                                 NaN
# 1      XC552408.mp3  aldfly                                 NaN
# 2      XC544552.mp3  aldfly                                 NaN
# 3      XC544551.mp3  aldfly                                 NaN
# 4      XC544550.mp3  aldfly                                 NaN
# ...             ...     ...                                 ...
# 43929  XC477608.mp3  yetvir  dowwoo buggna norpar norcar reshaw
# 43930  XC500348.mp3  yetvir                      reevir1 buggna
# ...
